# %%
import numpy as np
import matplotlib.pylab as plt

# %% [markdown]
# ### Sigmoid

# %% [markdown]
# $$sigmoid(x) = \frac{1}{1+e^{-x}}$$

# %% [markdown]
# $$= \frac{1}{1+exp(-x)}$$

# %%
def my_sigmoid(x):
  return 1 / (1+np.exp(-x))

# %% [markdown]
# ### Hyperbolic Tangent (*tanh*)

# %% [markdown]
# $$tanh(x) = \frac{1 - e^{-x}}{1 + e^{-x}} = \frac{2}{1+e^{-2x}}-1 = 2 \times sigmoid(2x) -1$$

# %%
def my_tanh(x):
  return 2*my_sigmoid(2*x)-1

# %% [markdown]
# ### Step function

# %%
def my_step(x):
  return np.array(x>0, dtype=np.int)

# %% [markdown]
# ### ReLU

# %% [markdown]
# ![Screen Shot 2020-10-07 at 5.07.26 PM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screen Shot 2020-10-07 at 5.08.09 PM.png](data:image/png;base64,...)

# %%
def my_relu(x):
  return np.maximum(0,x)

# %%
# https://stackoverflow.com/a/47936476
def my_relu2(x):
  return x*(x>0)

# %% [markdown]
# ### Test

# %%
x = np.arange(-10,10,0.1)

# %%
y1 = my_sigmoid(x)
y2 = my_tanh(x)
y3 = my_step(x)
y4 = my_relu2(x)

# %%
plt.plot(x,y1)
plt.plot(x,y2)
plt.plot(x,y3)
plt.plot(x,y4)
plt.legend(['sigmoid', 'tanh', 'step', 'relu'])
plt.grid()
